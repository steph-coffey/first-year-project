# %%
import streamline as s

# %%
wave, spec = s.CSRE(Rp = 7.118e6, Rs = 8.2927e7, Rref = 6.957e8, planet_name = 'trappist1b', star_name = 'trappist1')

# %%
fig, ax = s.plotting(wave, spec, Rp = 7.118e6, Rs = 8.2927e7, err = True)
# Out:
# Running Single Case for: NIRSpec Prism
# Optimization Reqested: Computing Duty Cycle
# Finished Duty Cycle Calc
# Starting Out of Transit Simulation
# End out of Transit
# Starting In Transit Simulation
# End In Transit

# %%
ax.set_ylim(7358, 7368)
fig
